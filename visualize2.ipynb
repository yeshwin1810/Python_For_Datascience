# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\keyes\Downloads\Customer Purchasing Behaviors.csv")
plt.plot(data['age'])
plt.plot(data['purchase_frequency'])
plt.title("Scatter Plot")
plt.ylabel("Age")
plt.xlabel('Frequency')
plt.show()

# %%
import numpy as np
from scipy import stats
temperatures = np.array([22,25,28,27,30,26,24,23,25,22,21,20])
mean_temp = np.mean(temperatures)
print("Mean: ",mean_temp)
# Out:
# Mean:  24.416666666666668

# %%
import numpy as np
import matplotlib.pyplot as plt
temperatures = np.array([22, 25, 28, 27, 30, 26, 24, 23, 25, 22, 21, 20])
mean_temp = np.mean(temperatures)
print("Mean: ", mean_temp)
plt.hist(temperatures, bins=5, edgecolor='black')
plt.title('Temperature Distribution')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.show()
# Out:
# Mean:  24.416666666666668

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
hours_studied = np.array([1,2,3,4,5,6,7]).reshape(-1,1)
exam_scores = np.array([45,50,55,60,65,70,75])
model = LinearRegression()
model.fit(hours_studied, exam_scores)
m = model.coef_[0]
c = model.intercept_
print(f"Regression equation : Exam Score = {m:.2f} * Hours Studied

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Data
hours_studied = np.array([1, 2, 3, 4, 5, 6, 7]).reshape(-1, 1)
exam_scores = np.array([45, 50, 55, 60, 65, 70, 75])

# Create and train the model
model = LinearRegression()
model.fit(hours_studied, exam_scores)

# Predict scores
predicted_scores = model.predict(hours_studied)

# Plotting the results
plt.scatter(hours_studied, exam_scores, color='blue', label='Actual Scores')
plt.plot(hours_studied, predicted_scores, color='red', label='Predicted Scores')
plt.title('Hours Studied vs Exam Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Scores')
plt.legend()
plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
data = {'Size':[1400,1600,1700,1875,1100],
        'Rooms': [3,4,4,5,2],
        'Price':[220,250,270,300,150]}
df = pd.DataFrame(data)
x = df[['Size','Rooms']]
y = df['Price']
model = LinearRegression()
model.fit(x,y)
beta_0 = model.intercept_
beta_1, beta_2 = model.coef_
print(f"Regression equation: Price = {beta_0:.2f} + {beta_1:.2f} * Size + {beta_2:.2f}*Rooms")
predicted_price = model.predict([[1500,3]])
print(f"Predicted Price for 1500 sq. ft. house with 3 rooms: {predicted_price[0]:.2f}")
# Out:
# Regression equation: Price = -88.55 + 0.25 * Size + -14.73*Rooms
# Predicted Price for 1500 sq. ft. house with 3 rooms: 238.18
# C:\Users\keyes\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\keyes\OneDrive\Desktop\IRIS_data.csv")

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head(100)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          0.2      Iris-setosa
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 4            5.0          3.6           1.4          0.2      Iris-setosa
# ..           ...          ...           ...          ...              ...
# 95           5.7          3.0           4.2          1.2  Iris-versicolor
# 96           5.7          2.9           4.2          1.3  Iris-versicolor
# 97           6.2          2.9           4.3          1.3  Iris-versicolor
# 98           5.1          2.5           3.0          1.1  Iris-versicolor
# 99           5.7          2.8           4.1          1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %%
df_setosa = df.loc[df['species']=='Iris-setosa']
df_virginica = df.loc[df['species']=='Iris-virginica']
df_versicolor = df.loc[df['species']=='Iris-versicolor']

# %%
plt.plot(df_setosa['sepal_length'], np.zeros_like(df_setosa['sepal_length']),'o')
plt.plot(df_virginica['sepal_length'], np.zeros_like(df_virginica['sepal_length']),'o')
plt.plot(df_versicolor['sepal_length'], np.zeros_like(df_versicolor['sepal_length']),'o')
plt.xlabel('Sepal length')
# Out:
# Text(0.5, 0, 'Sepal\xa0length')

# %%
plt.bar(df['species'], df['sepal_length'])
plt.xlabel('species')
# Out:
# Text(0.5, 0, 'species')

# %%
sns.FacetGrid(df, hue="species", height=5).map(plt.scatter, "sepal_length", "sepal_width").add_legend()

# %%
sns.pairplot(df,hue="species",size=3)
# Out:
# C:\Users\keyes\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\keyes\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\keyes\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\keyes\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...
