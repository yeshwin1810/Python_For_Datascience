# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\jayad\Downloads\Customer Purchasing Behaviors.csv")
plt.plot(data['age'])
plt.plot(data['purchase_frequency'])
plt.title("Line Plot")
plt.ylabel("Age")
plt.xlabel('Frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv(r"C:\Users\jayad\Downloads\Customer Purchasing Behaviors.csv")

plt.bar(data['age'], data['purchase_frequency'])

plt.title("Bar Chart")

plt.xlabel('frequency')
plt.ylabel('Age')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\jayad\Downloads\Customer Purchasing Behaviors.csv")
plt.hist(data['annual_income'])

plt.title("Histogram")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv(r"C:\Users\jayad\Downloads\Customer Purchasing Behaviors.csv")

sns.barplot(x='region',y='purchase_frequency', data=data, hue='region')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv(r"C:\Users\jayad\Downloads\Customer Purchasing Behaviors.csv")

sns.histplot(x='purchase_amount', data=data, kde=True, hue='region')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# reading the database
data = pd.read_csv(r"C:\Users\jayad\Downloads\Customer Purchasing Behaviors.csv")

# Scatter plot with day against tip
plt.scatter(data['age'], data['region'], c=data['loyalty_score'], s=data['purchase_amount'])

# Adding Title to the Plot
plt.title("Scatter Plot")

# Setting the X and Y labels
plt.xlabel('age')
plt.ylabel('frequency')

plt.colorbar()

plt.show()
